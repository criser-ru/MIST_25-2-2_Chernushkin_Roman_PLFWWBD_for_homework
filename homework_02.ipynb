# %%
N = int(input("Введите целое положительное число: "))
for i in range(1, N + 1):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# Введите целое положительное число:  15
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz

# %%
shopping_list = []

while True:
    print("Меню:")
    print("1. Добавить")
    print("2. Показать")
    print("3. Выйти")

    choice = input("Выберите действие: ")

    if choice == "1":
        item = input("Введите название продукта: ")
        shopping_list.append(item)
        print(f" {item} добавлено в список.")

    elif choice == "2":
        if len(shopping_list) == 0:
            print("Список покупок пуст.")
        else:
            print("Список покупок:")
            for index, item in enumerate(shopping_list, start=1):
                print(f"{index}. {item}")

    elif choice == "3":
        print("Программа завершена.")
        break

    else:
        print("Неизвестная команда, попробуйте снова.")
# Out:
# Меню:
# 1. Добавить
# 2. Показать
# 3. Выйти
# Выберите действие:  1
# Введите название продукта:  молоко
#  молоко добавлено в список.
# Меню:
# 1. Добавить
# 2. Показать
# 3. Выйти
# Выберите действие:  1
# Введите название продукта:  кефир
#  кефир добавлено в список.
# Меню:
# 1. Добавить
# 2. Показать
# 3. Выйти
# Выберите действие:  2
# Список покупок:
# 1. молоко
# 2. кефир
# Меню:
# 1. Добавить
# 2. Показать
# 3. Выйти
# Выберите действие:  3
# Программа завершена.
