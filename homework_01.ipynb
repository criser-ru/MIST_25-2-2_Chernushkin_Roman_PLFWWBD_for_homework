# %%
print("Меня зовут Роман, и я готов страдать на курсе!")
# Out:
# Меня зовут Роман, и я готов страдать на курсе!

# %% [markdown]
# Меня зовут Чернушкин Роман, я 2004 года рождения, на данный момент являюся магистрантом в МШИБС в НИТУ МИСиС.

# %% [markdown]
# Степень бакалавра я получил в МГТУ им. Н.Э. Баумана, и я не рекомендую туда поступать по многим причинам.

# %% [markdown]
# Абсолютно точно готов страдать на курсе,  ведь хочу научиться такому предмету, как "Языки программирования для работы с большими данными"

# %%
print(77%2)
# Out:
# 1

# %%
print(22//2)
# Out:
# 11

# %%
print(86**7)
# Out:
# 34792782221696

# %%
print(3686400**0.5)
# Out:
# 1920.0
